# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Customer-Churn-Records.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age
# 0          1    15634602  Hargrave          619    France  Female   42  \
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember
# 0       2       0.00              1          1               1  \
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type
# 0        101348.88       1         1                   2   DIAMOND  \
# ...

# %%
columns_to_remove=['RowNumber','CustomerId','Surname']
df_1=df.drop(columns=columns_to_remove, axis=1)

# %%
df_1.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts
# 0          619    France  Female   42       2       0.00              1  \
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain
# 0          1               1        101348.88       1         1  \
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction Score Card Type  Point Earned
# 0                   2   DIAMOND           464
# 1                   3   DIAMOND           456
# ...

# %%
df_1.isnull().sum()
# Out:
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
numerical_variables = ['CreditScore','Age','Tenure','Balance','NumOfProducts','EstimatedSalary','Satisfaction Score','Point Earned']
df_numerical = df_1[numerical_variables]
df_numerical.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  EstimatedSalary
# 0          619   42       2       0.00              1        101348.88  \
# 1          608   41       1   83807.86              1        112542.58
# 2          502   42       8  159660.80              3        113931.57
# 3          699   39       1       0.00              2         93826.63
# 4          850   43       2  125510.82              1         79084.10
#
#    Satisfaction Score  Point Earned
# 0                   2           464
# 1                   3           456
# 2                   3           377
# 3                   5           350
# 4                   5           425

# %%
correlation_matrix = df_numerical.corr()

# Create the correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', square=True)

# Set the title
plt.title('Correlation Heatmap')

# Show the plot
plt.show()

# %%
categorical_variables = ['Geography','Gender','HasCrCard','IsActiveMember','Complain','Card Type']
df_cat = df_1[categorical_variables]
df_cat.head()
# Out:
#   Geography  Gender  HasCrCard  IsActiveMember  Complain Card Type
# 0    France  Female          1               1         1   DIAMOND
# 1     Spain  Female          0               1         1   DIAMOND
# 2    France  Female          1               0         1   DIAMOND
# 3    France  Female          0               0         0      GOLD
# 4     Spain  Female          1               1         0      GOLD

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['Geography'].hist()

# Set the title and labels
plt.title('Histogram of Geography')
plt.xlabel('Geography')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['Gender'].hist()

# Set the title and labels
plt.title('Histogram of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['HasCrCard'].hist()

# Set the title and labels
plt.title('Histogram of HasCrCard')
plt.xlabel('HasCrCard')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['IsActiveMember'].hist()

# Set the title and labels
plt.title('Histogram of IsActiveMember')
plt.xlabel('IsActiveMember')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['Complain'].hist()

# Set the title and labels
plt.title('Histogram of Complain')
plt.xlabel('Complain')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
df_cat['Card Type'].hist()

# Set the title and labels
plt.title('Histogram of Card Type')
plt.xlabel('Card Type')
plt.ylabel('Frequency')

# Show the plot
plt.show()
