# %%
import pandas as pd

# %%
df = pd.read_csv('Customer-Churn-Records.csv')
columns_to_remove=['RowNumber','CustomerId','Surname']
df=df.drop(columns=columns_to_remove, axis=1)

# %%
# Perform one-hot encoding
#France as reference level
df_1 =  pd.get_dummies(df, columns=['Geography'], prefix='', prefix_sep='').drop('France', axis=1)
df_1.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0          619  Female   42       2       0.00              1          1  \
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
# 3          699  Female   39       1       0.00              2          0
# 4          850  Female   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score
# 0               1        101348.88       1         1                   2  \
# 1               1        112542.58       0         1                   3
# 2               0        113931.57       1         1                   3
# 3               0         93826.63       0         0                   5
# 4               1         79084.10       0         0                   5
#
#   Card Type  Point Earned  Germany  Spain
# 0   DIAMOND           464    False  False
# ...

# %%
df_1[['Germany','Spain']] = df_1[['Germany','Spain']].astype(int)
df_1.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0          619  Female   42       2       0.00              1          1  \
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
# 3          699  Female   39       1       0.00              2          0
# 4          850  Female   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score
# 0               1        101348.88       1         1                   2  \
# 1               1        112542.58       0         1                   3
# 2               0        113931.57       1         1                   3
# 3               0         93826.63       0         0                   5
# 4               1         79084.10       0         0                   5
#
#   Card Type  Point Earned  Germany  Spain
# 0   DIAMOND           464        0      0
# ...

# %%
# Define the mapping
gender_mapping = {'Male': 0, 'Female': 1}
# Transform gender column
df_1['Gender'] = df_1['Gender'].map(gender_mapping)
df_1.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0          619       1   42       2       0.00              1          1  \
# 1          608       1   41       1   83807.86              1          0
# 2          502       1   42       8  159660.80              3          1
# 3          699       1   39       1       0.00              2          0
# 4          850       1   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score
# 0               1        101348.88       1         1                   2  \
# 1               1        112542.58       0         1                   3
# 2               0        113931.57       1         1                   3
# 3               0         93826.63       0         0                   5
# 4               1         79084.10       0         0                   5
#
#   Card Type  Point Earned  Germany  Spain
# 0   DIAMOND           464        0      0
# ...

# %%
# Perform one-hot encoding
#Silver as reference level
df_2 =  pd.get_dummies(df_1, columns=['Card Type'], prefix='', prefix_sep='').drop('SILVER', axis=1)
df_2[['DIAMOND','GOLD','PLATINUM']] = df_2[['DIAMOND','GOLD','PLATINUM']].astype(int)
df_2.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard
# 0          619       1   42       2       0.00              1          1  \
# 1          608       1   41       1   83807.86              1          0
# 2          502       1   42       8  159660.80              3          1
# 3          699       1   39       1       0.00              2          0
# 4          850       1   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score
# 0               1        101348.88       1         1                   2  \
# 1               1        112542.58       0         1                   3
# 2               0        113931.57       1         1                   3
# 3               0         93826.63       0         0                   5
# 4               1         79084.10       0         0                   5
#
#    Point Earned  Germany  Spain  DIAMOND  GOLD  PLATINUM
# ...

# %%
# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# %%
numerical_variables = ['CreditScore','Balance','EstimatedSalary','Point Earned']
df_2[numerical_variables] = scaler.fit_transform(df_2[numerical_variables])
df_2.head()
# Out:
#    CreditScore  Gender  Age  Tenure   Balance  NumOfProducts  HasCrCard
# 0        0.538       1   42       2  0.000000              1          1  \
# 1        0.516       1   41       1  0.334031              1          0
# 2        0.304       1   42       8  0.636357              3          1
# 3        0.698       1   39       1  0.000000              2          0
# 4        1.000       1   43       2  0.500246              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Complain  Satisfaction Score
# 0               1         0.506735       1         1                   2  \
# 1               1         0.562709       0         1                   3
# 2               0         0.569654       1         1                   3
# 3               0         0.469120       0         0                   5
# 4               1         0.395400       0         0                   5
#
#    Point Earned  Germany  Spain  DIAMOND  GOLD  PLATINUM
# ...

# %%
df_2.to_csv('transformed_df.csv',index=0)
